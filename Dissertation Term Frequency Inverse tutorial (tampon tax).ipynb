# %%
# !pip install sklearn
# Out:
# Requirement already satisfied: sklearn in ./opt/anaconda3/lib/python3.8/site-packages (0.0)
# Requirement already satisfied: scikit-learn in ./opt/anaconda3/lib/python3.8/site-packages (from sklearn) (0.23.2)
# Requirement already satisfied: numpy>=1.13.3 in ./opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.19.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->sklearn) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in ./opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->sklearn) (0.17.0)
# Requirement already satisfied: scipy>=0.19.1 in ./opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.5.2)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
pd.set_option("max_rows", 600)
from pathlib import Path  
import glob

# %%
#change directory path
#use text processed files
#change from .csv to .txt
directory_path = "Desktop/TFIDF/TFIDF_processed"

# %%
text_files = glob.glob(f"{directory_path}/*.txt")

# %%
text_files
# Out:
# ['Desktop/TFIDF/TFIDF_processed/Factiva_Tampon_Tax.txt',
#  'Desktop/TFIDF/TFIDF_processed/Twitter_Tampon_Tax_Political.txt',
#  'Desktop/TFIDF/TFIDF_processed/Reddit_Tampon_Tax_Political.txt',
#  'Desktop/TFIDF/TFIDF_processed/Twitter_Tampon_Tax_All.txt']

# %%
text_titles = [Path(text).stem for text in text_files]

# %%
text_titles
# Out:
# ['Factiva_Tampon_Tax',
#  'Twitter_Tampon_Tax_Political',
#  'Reddit_Tampon_Tax_Political',
#  'Twitter_Tampon_Tax_All']

# %%
tfidf_vectorizer = TfidfVectorizer(input='filename', stop_words='english')

# %%
tfidf_vector = tfidf_vectorizer.fit_transform(text_files)

# %%
tfidf_df = pd.DataFrame(tfidf_vector.toarray(), index=text_titles, columns=tfidf_vectorizer.get_feature_names())

# %%
tfidf_df.loc['00_Document Frequency'] = (tfidf_df > 0).sum()

# %%
#change slice words
tfidf_slice = tfidf_df[['remove','sign', 'end','repeal', 'vote', 'gov', 'eliminate']]
tfidf_slice.sort_index().round(decimals=2)
# Out:
#                               remove  sign   end  repeal  vote   gov  \
# 00_Document Frequency           3.00  4.00  3.00    4.00  3.00  4.00
# Factiva_Tampon_Tax              0.02  0.02  0.07    0.03  0.04  0.00
# Reddit_Tampon_Tax_Political     0.22  0.24  0.16    0.11  0.00  0.18
# Twitter_Tampon_Tax_All          0.03  0.08  0.00    0.04  0.04  0.01
# Twitter_Tampon_Tax_Political    0.00  0.02  0.00    0.02  0.12  0.03
#
#                               eliminate
# 00_Document Frequency              4.00
# Factiva_Tampon_Tax                 0.03
# Reddit_Tampon_Tax_Political        0.19
# Twitter_Tampon_Tax_All             0.06
# Twitter_Tampon_Tax_Political       0.02

# %%
tfidf_df = tfidf_df.drop('00_Document Frequency', errors='ignore')

# %%
tfidf_df.stack().reset_index()
# Out:
#                       level_0     level_1    0
# 0          Factiva_Tampon_Tax        1019  0.0
# 1          Factiva_Tampon_Tax        10am  0.0
# 2          Factiva_Tampon_Tax        10th  0.0
# 3          Factiva_Tampon_Tax          11  0.0
# 4          Factiva_Tampon_Tax         110  0.0
# ...                       ...         ...  ...
# 51067  Twitter_Tampon_Tax_All      zucker  0.0
# 51068  Twitter_Tampon_Tax_All  zuckerberg  0.0
# 51069  Twitter_Tampon_Tax_All   zukiewicz  0.0
# 51070  Twitter_Tampon_Tax_All      zumiez  0.0
# 51071  Twitter_Tampon_Tax_All          àa  0.0
#
# [51072 rows x 3 columns]

# %%
tfidf_df = tfidf_df.stack().reset_index()

# %%
tfidf_df = tfidf_df.rename(columns={0:'tfidf', 'level_0': 'document','level_1': 'term', 'level_2': 'term'})

# %%
tfidf_df.sort_values(by=['document','tfidf'], ascending=[True,False]).groupby(['document']).head(15)
# Out:
#                            document                 term     tfidf
# 10055            Factiva_Tampon_Tax                 sale  0.209666
# 10046            Factiva_Tampon_Tax                 said  0.195710
# 9869             Factiva_Tampon_Tax                right  0.179218
# 3170             Factiva_Tampon_Tax             document  0.162368
# 4050             Factiva_Tampon_Tax             feminine  0.132578
# 12699            Factiva_Tampon_Tax                 year  0.120616
# 8558             Factiva_Tampon_Tax              percent  0.120482
# 7111             Factiva_Tampon_Tax                 make  0.118268
# 12717            Factiva_Tampon_Tax                 york  0.115299
# 12611            Factiva_Tampon_Tax                 word  0.109733
# 8552             Factiva_Tampon_Tax               people  0.105331
# 9198             Factiva_Tampon_Tax               public  0.100904
# 776              Factiva_Tampon_Tax           associated  0.099968
# 6717             Factiva_Tampon_Tax                  law  0.099573
# 6719             Factiva_Tampon_Tax             lawmaker  0.097541
# 27035   Reddit_Tampon_Tax_Political             business  0.275123
# 36904   Reddit_Tampon_Tax_Political               taxcut  0.244271
# 36023   Reddit_Tampon_Tax_Political                 sign  0.236732
# 35177   Reddit_Tampon_Tax_Political               remove  0.222736
# 28322   Reddit_Tampon_Tax_Political               delete  0.220099
# 30547   Reddit_Tampon_Tax_Political              holiday  0.220099
# 29005   Reddit_Tampon_Tax_Political            eliminate  0.191206
# 30142   Reddit_Tampon_Tax_Political                  gov  0.182101
# 26275   Reddit_Tampon_Tax_Political               asking  0.178189
# 36858   Reddit_Tampon_Tax_Political               tampon  0.165074
# 29104   Reddit_Tampon_Tax_Political                  end  0.155915
# 33931   Reddit_Tampon_Tax_Political                panel  0.155915
# 27806   Reddit_Tampon_Tax_Political             consider  0.145681
# 33679   Reddit_Tampon_Tax_Political                   ok  0.145681
# 30465   Reddit_Tampon_Tax_Political               herald  0.137562
# 49198        Twitter_Tampon_Tax_All                state  0.185522
# 48001        Twitter_Tampon_Tax_All           repsargent  0.166089
# 44759        Twitter_Tampon_Tax_All           jweisswolf  0.159007
# 45361        Twitter_Tampon_Tax_All               luxury  0.154772
# 40087        Twitter_Tampon_Tax_All               change  0.147660
# 38783        Twitter_Tampon_Tax_All              amazing  0.140088
# 44166        Twitter_Tampon_Tax_All                   im  0.136430
# 45703        Twitter_Tampon_Tax_All  menstruationmatters  0.136430
# 47209        Twitter_Tampon_Tax_All             prachigu  0.121593
# 42385        Twitter_Tampon_Tax_All                fight  0.121157
# 49486        Twitter_Tampon_Tax_All              support  0.117371
# 48359        Twitter_Tampon_Tax_All                 sale  0.114531
# 39024        Twitter_Tampon_Tax_All              article  0.113585
# 45318        Twitter_Tampon_Tax_All                 love  0.113585
# 45987        Twitter_Tampon_Tax_All           msmagazine  0.102887
# 20818  Twitter_Tampon_Tax_Political           nygovcuomo  0.271192
# 24090  Twitter_Tampon_Tax_Political               tampon  0.242646
# 19114  Twitter_Tampon_Tax_Political        jerrybrowngov  0.199826
# 21835  Twitter_Tampon_Tax_Political              product  0.199142
# 23950  Twitter_Tampon_Tax_Political              support  0.150221
# 19223  Twitter_Tampon_Tax_Political           jweisswolf  0.142733
# 20451  Twitter_Tampon_Tax_Political           msmagazine  0.128460
# 21673  Twitter_Tampon_Tax_Political             prachigu  0.128460
# 23662  Twitter_Tampon_Tax_Political                state  0.127110
# 25336  Twitter_Tampon_Tax_Political                woman  0.127110
# 13488  Twitter_Tampon_Tax_Political              article  0.115555
# 20907  Twitter_Tampon_Tax_Political                 ohio  0.115555
# 25053  Twitter_Tampon_Tax_Political                 vote  0.115555
# 23260  Twitter_Tampon_Tax_Political               signed  0.113368
# 13247  Twitter_Tampon_Tax_Political              amazing  0.103999

# %%
top_tfidf = tfidf_df.sort_values(by=['document','tfidf'], ascending=[True,False]).groupby(['document']).head(10)

# %%
top_tfidf[top_tfidf['term'].str.contains('petition')]
# Out:
# Empty DataFrame
# Columns: [document, term, tfidf]
# Index: []

# %%
top_tfidf[top_tfidf['document'].str.contains('Reddit')]
# Out:
#                           document       term     tfidf
# 27035  Reddit_Tampon_Tax_Political   business  0.275123
# 36904  Reddit_Tampon_Tax_Political     taxcut  0.244271
# 36023  Reddit_Tampon_Tax_Political       sign  0.236732
# 35177  Reddit_Tampon_Tax_Political     remove  0.222736
# 28322  Reddit_Tampon_Tax_Political     delete  0.220099
# 30547  Reddit_Tampon_Tax_Political    holiday  0.220099
# 29005  Reddit_Tampon_Tax_Political  eliminate  0.191206
# 30142  Reddit_Tampon_Tax_Political        gov  0.182101
# 26275  Reddit_Tampon_Tax_Political     asking  0.178189
# 36858  Reddit_Tampon_Tax_Political     tampon  0.165074

# %%
# !pip install altair
# Out:
# Requirement already satisfied: altair in ./opt/anaconda3/lib/python3.8/site-packages (4.1.0)
# Requirement already satisfied: jsonschema in ./opt/anaconda3/lib/python3.8/site-packages (from altair) (3.2.0)
# Requirement already satisfied: toolz in ./opt/anaconda3/lib/python3.8/site-packages (from altair) (0.11.1)
# Requirement already satisfied: entrypoints in ./opt/anaconda3/lib/python3.8/site-packages (from altair) (0.3)
# Requirement already satisfied: numpy in ./opt/anaconda3/lib/python3.8/site-packages (from altair) (1.19.2)
# Requirement already satisfied: pandas>=0.18 in ./opt/anaconda3/lib/python3.8/site-packages (from altair) (1.3.3)
# Requirement already satisfied: jinja2 in ./opt/anaconda3/lib/python3.8/site-packages (from altair) (2.11.2)
# Requirement already satisfied: pyrsistent>=0.14.0 in ./opt/anaconda3/lib/python3.8/site-packages (from jsonschema->altair) (0.17.3)
# Requirement already satisfied: six>=1.11.0 in ./opt/anaconda3/lib/python3.8/site-packages (from jsonschema->altair) (1.15.0)
# Requirement already satisfied: setuptools in ./opt/anaconda3/lib/python3.8/site-packages (from jsonschema->altair) (50.3.1.post20201107)
# Requirement already satisfied: attrs>=17.4.0 in ./opt/anaconda3/lib/python3.8/site-packages (from jsonschema->altair) (20.3.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in ./opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.18->altair) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in ./opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.18->altair) (2020.1)
# Requirement already satisfied: MarkupSafe>=0.23 in ./opt/anaconda3/lib/python3.8/site-packages (from jinja2->altair) (1.1.1)

# %%
import altair as alt
import numpy as np

# %%
import altair as alt
import numpy as np

# Terms in this list will get a red dot in the visualization - update accordingly
term_list = ['remove','sign', 'end', 'repeal', 'vote', 'eliminate', 'nygovcuomo','jerrybrowngov']

# adding a little randomness to break ties in term ranking
top_tfidf_plusRand = top_tfidf.copy()
top_tfidf_plusRand['tfidf'] = top_tfidf_plusRand['tfidf'] + np.random.rand(top_tfidf.shape[0])*0.0001

# base for all visualizations, with rank calculation
base = alt.Chart(top_tfidf_plusRand).encode(
    x = 'rank:O',
    y = 'document:N'
).transform_window(
    rank = "rank()",
    sort = [alt.SortField("tfidf", order="descending")],
    groupby = ["document"],
)

# heatmap specification
heatmap = base.mark_rect().encode(
    color = 'tfidf:Q'
)

# red circle over terms in above list
circle = base.mark_circle(size=100).encode(
    color = alt.condition(
        alt.FieldOneOfPredicate(field='term', oneOf=term_list),
        alt.value('red'),
        alt.value('#FFFFFF00')        
    )
)

# text labels, white for darker heatmap colors
text = base.mark_text(baseline='middle').encode(
    text = 'term:N',
    color = alt.condition(alt.datum.tfidf >= 0.23, alt.value('white'), alt.value('black'))
)

# display the three superimposed visualizations
(heatmap + circle + text).properties(width = 1300)
# Out:
# alt.LayerChart(...)
